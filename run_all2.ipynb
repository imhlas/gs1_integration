# %%
from src.pipelines import *
from src.config import SINCE_ISO 

#run_full_pipeline(spark, dbutils)

updated_gtins = run_changes_pipeline(spark, dbutils, since_iso=SINCE_ISO)

print("Ensimmäiset 20 päivittynyttä GTINiä:")
print(updated_gtins[:20])
